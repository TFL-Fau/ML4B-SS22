# %%
import streamlit as st
import jsonlines
import random
import pandas as pd
import json
import fileinput
import numpy as np
from pprint import pprint
from wordcloud import WordCloud
from textblob_de import TextBlobDE as TextBlob
import re
import matplotlib.pyplot as plt
# Out:
# 2022-05-30 20:30:30.821 INFO    numexpr.utils: NumExpr defaulting to 8 threads.

# %%
#Importing Dataset
olafScholzJsonLines = jsonlines.open("OlafScholz.jl")

olafScholzTwitter = pd.read_json("OlafScholz.jl", lines = True)
print("Datensatzlänge: " + str(olafScholzTwitter.info()))

print(olafScholzTwitter.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   http_status   65 non-null     int64
#  1   account_name  65 non-null     object
#  2   account_data  65 non-null     object
#  3   params        65 non-null     object
#  4   response      65 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.7+ KB
# Datensatzlänge: None
#    http_status account_name  \
# 0          200   OlafScholz
# 1          200   OlafScholz
# 2          200   OlafScholz
# 3          200   OlafScholz
# 4          200   OlafScholz
#
#                                         account_data  \
# 0  {'Name': 'Scholz, Olaf', 'Partei': 'SPD', 'id'...
# 1  {'Name': 'Scholz, Olaf', 'Partei': 'SPD', 'id'...
# 2  {'Name': 'Scholz, Olaf', 'Partei': 'SPD', 'id'...
# 3  {'Name': 'Scholz, Olaf', 'Partei': 'SPD', 'id'...
# 4  {'Name': 'Scholz, Olaf', 'Partei': 'SPD', 'id'...
#
#                                               params  \
# 0  [[query, from:OlafScholz], [max_results, 100],...
# 1  [[query, from:OlafScholz], [max_results, 100],...
# 2  [[query, from:OlafScholz], [max_results, 100],...
# 3  [[query, from:OlafScholz], [max_results, 100],...
# 4  [[query, from:OlafScholz], [max_results, 100],...
#
#                                             response
# 0  {'data': [{'context_annotations': [{'domain': ...
# 1  {'data': [{'in_reply_to_user_id': '38150247', ...
# 2  {'data': [{'conversation_id': '144576374098134...
# 3  {'data': [{'created_at': '2021-09-02T13:33:12....
# 4  {'data': [{'conversation_id': '141999599421797...

# %%
# Reply Dataframe
# Importing Data into final Dataframe for ML
replyDataFrame = pd.DataFrame(columns = ["tweetid", "date", "time", "user", "text"])
print(replyDataFrame.head())
iterator = 0

for line in olafScholzJsonLines:
    keyResponse = line["response"]
    data = keyResponse["data"]
    newDataRow = [None, None, None, None, None]
    userName = line["account_name"]
    newDataRow[4] = userName
    keyResponse = line["response"]
    data = keyResponse["data"]


    for tweet in data:

        tweetTarget = 1
       
        tweetID = tweet["id"]
        authorID = tweet["author_id"]
        tweetDate = tweet["created_at"][0:10]
        tweetTime = tweet["created_at"][11:19]
        tweetText = tweet["text"]        
        newDataRow[0] = tweetID
        newDataRow[1] = tweetDate
        newDataRow[2] = tweetTime
        newDataRow[3] = authorID
        newDataRow[4] = tweetText
        replyDataFrame.loc[len(replyDataFrame)] = newDataRow
    iterator += 1
# Out:
# Empty DataFrame
# Columns: [tweetid, date, time, user, text]
# Index: []

# %%
#print(dir(replyDataFrame))
print(len(replyDataFrame))
print(replyDataFrame.shape)
print(replyDataFrame.head())
# Out:
# 6419
# (6419, 5)
#                tweetid        date      time      user  \
# 0  1515588838562971650  2022-04-17  07:11:52  38150247
# 1  1514644785818058757  2022-04-14  16:40:32  38150247
# 2  1514291545742184451  2022-04-13  17:16:53  38150247
# 3  1514256817613905929  2022-04-13  14:58:53  38150247
# 4  1513955069867274245  2022-04-12  18:59:51  38150247
#
#                                                 text
# 0  RT @Bundeskanzler: Ich wünsche Ihnen und Ihren...
# 1  RT @Bundeskanzler: Meine Solidarität gilt @Kar...
# 2  RT @Bundeskanzler: Sie haben Hilfe organisiert...
# 3  RT @Bundeskanzler: Verantwortung übernehmen he...
# 4  RT @Bundeskanzler: Die Sanktionen gegen #Russl...

# %%
print("----")
print(replyDataFrame[replyDataFrame["text"].str.contains("RT @Bundeskanzler:")].sort_values("date",ascending = "true").head())
# Out:
# ----
#                 tweetid        date      time      user  \
# 53  1493195813245313024  2022-02-14  12:09:58  38150247
# 52  1493599012691365903  2022-02-15  14:52:09  38150247
# 51  1493602211829587986  2022-02-15  15:04:51  38150247
# 50  1494003008283287560  2022-02-16  17:37:29  38150247
# 49  1494245849085493251  2022-02-17  09:42:26  38150247
#
#                                                  text
# 53  RT @Bundeskanzler: Auf dem Weg in die #Ukraine...
# 52  RT @Bundeskanzler: Der Frieden und die Sicherh...
# 51  RT @Bundeskanzler: Ich habe Präsident #Putin i...
# 50  RT @Bundeskanzler: Die #Corona-Regeln zeigen d...
# 49  RT @Bundeskanzler: Gestern Abend habe ich mit ...

# %%
#testing
print(replyDataFrame["text"].str.contains("RT @Bundeskanzler").head())
print(replyDataFrame["text"].str.contains("RT @Bundeskanzler").count())
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: text, dtype: bool
# 6419

# %%
#cleansedTweetDF = replyDataFrame[replyDataFrame["text"].str.contains("RT @Bundeskanzler:") or replyDataFrame["text"].str.contains("!RT @") ]
print("Size of dataframe :\n"+ str(replyDataFrame.count())+"\n----")
maskBundesKanz = replyDataFrame["text"].str.contains("RT @Bundeskanzler:")
maskNoRT = replyDataFrame["text"].str.contains("RT @")==False
print("Size of dataframe with RT @Bundeskanzler:\n" + str(replyDataFrame[maskBundesKanz].count())+"\n----")
print("Size of dataframe without RT @:\n" + str(replyDataFrame[maskNoRT].count())+"\n----")
#cleansedTweetDF contains all Tweets posted directly by Olaf before or after being Kanzler
cleansedTweetDF = replyDataFrame[maskBundesKanz | maskNoRT]
print("Size of cleansedTweetDF @:\n" + str(cleansedTweetDF.count())+"\n----")
print(cleansedTweetDF.head())
#cleansedTweetDF has "RT @Bundeskanzler:" still in the tweet. To not have any issues with ML we removed that part of the Tweet in the following parts
# Out:
# Size of dataframe :
# tweetid    6419
# date       6419
# time       6419
# user       6419
# text       6419
# dtype: int64
# ----
# Size of dataframe with RT @Bundeskanzler:
# tweetid    48
# date       48
# time       48
# user       48
# text       48
# dtype: int64
# ----
# Size of dataframe without RT @:
# tweetid    4071
# date       4071
# time       4071
# user       4071
# text       4071
# dtype: int64
# ----
# Size of cleansedTweetDF @:
# tweetid    4119
# date       4119
# time       4119
# user       4119
# text       4119
# dtype: int64
# ----
#                tweetid        date      time      user  \
# 0  1515588838562971650  2022-04-17  07:11:52  38150247
# 1  1514644785818058757  2022-04-14  16:40:32  38150247
# 2  1514291545742184451  2022-04-13  17:16:53  38150247
# 3  1514256817613905929  2022-04-13  14:58:53  38150247
# 4  1513955069867274245  2022-04-12  18:59:51  38150247
#
#                                                 text
# 0  RT @Bundeskanzler: Ich wünsche Ihnen und Ihren...
# 1  RT @Bundeskanzler: Meine Solidarität gilt @Kar...
# 2  RT @Bundeskanzler: Sie haben Hilfe organisiert...
# 3  RT @Bundeskanzler: Verantwortung übernehmen he...
# 4  RT @Bundeskanzler: Die Sanktionen gegen #Russl...

# %%
# Removing the Text \"RT @Bundeskanzler:\" from the text\n
print("ReplyDataframe: \n" + str(replyDataFrame[maskBundesKanz].count()))
cleansedAtBundKanzDF = replyDataFrame[maskBundesKanz].copy()
cleansedAtBundKanzDF.text = cleansedAtBundKanzDF.text.str.strip("RT @Bundeskanzler: ")
print(cleansedAtBundKanzDF.head())
# Out:
# ReplyDataframe:
# tweetid    48
# date       48
# time       48
# user       48
# text       48
# dtype: int64
#                tweetid        date      time      user  \
# 0  1515588838562971650  2022-04-17  07:11:52  38150247
# 1  1514644785818058757  2022-04-14  16:40:32  38150247
# 2  1514291545742184451  2022-04-13  17:16:53  38150247
# 3  1514256817613905929  2022-04-13  14:58:53  38150247
# 4  1513955069867274245  2022-04-12  18:59:51  38150247
#
#                                                 text
# 0  Ich wünsche Ihnen und Ihren Familien frohe #Os...
# 1  Meine Solidarität gilt @Karl_Lauterbach: Jeder...
# 2  Sie haben Hilfe organisiert, Kräfte gebündelt ...
# 3  Verantwortung übernehmen heißt: Deutschland li...
# 4  Die Sanktionen gegen #Russland sind notwendig ...

# %%
#appending the sliced versions to the Dataframe and resulting in the expected 4119 Tweets
cleansedTweetDFShort = replyDataFrame[maskNoRT].append(cleansedAtBundKanzDF)
print(cleansedTweetDFShort.count())
print(cleansedTweetDFShort.sort_values("date",ascending = False).head())
# Out:
# tweetid    4119
# date       4119
# time       4119
# user       4119
# text       4119
# dtype: int64
#                tweetid        date      time      user  \
# 0  1515588838562971650  2022-04-17  07:11:52  38150247
# 1  1514644785818058757  2022-04-14  16:40:32  38150247
# 2  1514291545742184451  2022-04-13  17:16:53  38150247
# 3  1514256817613905929  2022-04-13  14:58:53  38150247
# 4  1513955069867274245  2022-04-12  18:59:51  38150247
#
#                                                 text
# 0  Ich wünsche Ihnen und Ihren Familien frohe #Os...
# 1  Meine Solidarität gilt @Karl_Lauterbach: Jeder...
# 2  Sie haben Hilfe organisiert, Kräfte gebündelt ...
# 3  Verantwortung übernehmen heißt: Deutschland li...
# 4  Die Sanktionen gegen #Russland sind notwendig ...

# %%
# Tobias 29.05.22 and 30.05.22

# Starting preparing for machine learning

# Making statement text in lower case

cleansedTweetDFShort

def clean(text):
    cleansedTweetDFShort['text'] = cleansedTweetDFShort['text'].str.replace('@[A-Za-z0-9]+\s?', '', regex=True)
    text = re.sub(r'@[A-Za-z0-9]+\s?', '', text) #Removed Mentions
    text = re.sub(r'#', '', text) #Removed #
    text = re.sub(r'(.)1+', r'1', text) #cleaned single letters
    text = re.sub('((www.[^s]+)|(https?://[^s]+))','',text) #Removes links
    text = re.sub('@','',text) #Remove @
    
    return text

cleansedTweetDFShort['text'] = cleansedTweetDFShort['text'].apply(clean)

cleansedTweetDFShort
# Out:
#                 tweetid        date      time      user  \
# 12  1508125473842335749  2022-03-27  16:55:07  38150247
# 21  1504398354565976070  2022-03-17  10:04:52  38150247
# 54  1492872048120668161  2022-02-13  14:43:27  38150247
# 55  1492074452796022791  2022-02-11  09:54:05  38150247
# 56  1492074451432873985  2022-02-11  09:54:05  38150247
# ..                  ...         ...       ...       ...
# 49  1494245849085493251  2022-02-17  09:42:26  38150247
# 50  1494003008283287560  2022-02-16  17:37:29  38150247
# 51  1493602211829587986  2022-02-15  15:04:51  38150247
# 52  1493599012691365903  2022-02-15  14:52:09  38150247
# 53  1493195813245313024  2022-02-14  12:09:58  38150247
#
#                                                  text
# 12  Die Saarländerinnen und Saarländer haben sich ...
# 21  Meine persönliche Position ist längst bekannt:...
# 54  Ich freue mich, wenn Sie und Ihr mir ab heute ...
# 55  Für die aktuelle Welle der Pandemie gibt es An...
# 56  Die Corona-Pandemie und auch die Flutkatastrop...
# ..                                                ...
# 49  Gestern Abend habe ich mit Biden zur Situation...
# 50  Die Corona-Regeln zeigen die erhoffte Wirkung....
# 51  Ich habe Präsident Putin in Moskau verdeutlich...
# 52  Der Frieden und die Sicherheit in Europa sind ...
# 53  Auf dem Weg in die Ukraine. Heute in Kiew und ...
#
# [4119 rows x 5 columns]

# %%
cleansedTweetDFShort = cleansedTweetDFShort.astype({'text':'string'})
print(cleansedTweetDFShort.dtypes)
cleansedTweetDFShort.head()
# Out:
# tweetid    object
# date       object
# time       object
# user       object
# text       string
# dtype: object
#                 tweetid        date      time      user  \
# 12  1508125473842335749  2022-03-27  16:55:07  38150247
# 21  1504398354565976070  2022-03-17  10:04:52  38150247
# 54  1492872048120668161  2022-02-13  14:43:27  38150247
# 55  1492074452796022791  2022-02-11  09:54:05  38150247
# 56  1492074451432873985  2022-02-11  09:54:05  38150247
#
#                                                  text
# 12  Die Saarländerinnen und Saarländer haben sich ...
# 21  Meine persönliche Position ist längst bekannt:...
# 54  Ich freue mich, wenn Sie und Ihr mir ab heute ...
# 55  Für die aktuelle Welle der Pandemie gibt es An...
# 56  Die Corona-Pandemie und auch die Flutkatastrop...

# %%
cleansedTweetDFShort10 = cleansedTweetDFShort[:100].copy()
cleansedTweetDFShort10
# Out:
#                  tweetid        date      time      user  \
# 12   1508125473842335749  2022-03-27  16:55:07  38150247
# 21   1504398354565976070  2022-03-17  10:04:52  38150247
# 54   1492872048120668161  2022-02-13  14:43:27  38150247
# 55   1492074452796022791  2022-02-11  09:54:05  38150247
# 56   1492074451432873985  2022-02-11  09:54:05  38150247
# ..                   ...         ...       ...       ...
# 169  1456191852026159105  2021-11-04  09:29:26  38150247
# 172  1454008788638474240  2021-10-29  08:54:44  38150247
# 174  1453697312149151747  2021-10-28  12:17:02  38150247
# 176  1453279700990763012  2021-10-27  08:37:36  38150247
# 177  1453000642365100052  2021-10-26  14:08:43  38150247
#
#                                                   text
# 12   Die Saarländerinnen und Saarländer haben sich ...
# 21   Meine persönliche Position ist längst bekannt:...
# 54   Ich freue mich, wenn Sie und Ihr mir ab heute ...
# 55   Für die aktuelle Welle der Pandemie gibt es An...
# 56   Die Corona-Pandemie und auch die Flutkatastrop...
# ..                                                 ...
# 169  Heute jährt sich das Auffliegen des rechtsextr...
# 172  Lieber Norbert, vielen Dank für das große Enga...
# 174  In der Bundesregierung und auch auf anderen Eb...
# 176  Vielen Dank für die Einladung zum Kongress, un...
# 177  Und auch dir, liebe Aydan , meine herzlichsten...
#
# [100 rows x 5 columns]

# %%
#Get Polarity and Subjectivity

# Subjectivity quantifies the amount of personal opinion and factual information contained in the text. 
# The higher subjectivity means that the text contains personal opinion rather than factual information. 
# 0 means low personal opinion and 1 a lot of personal opinion

def getS (text):
    return TextBlob(text).sentiment.subjectivity

# Polarity lies between [-1,1], -1 defines a negative sentiment and 1 defines a positive sentiment.

def getP (text):
    return TextBlob(text).sentiment.polarity


cleansedTweetDFShort10['Personal Opinion (Subjectivity)'] = cleansedTweetDFShort10['text'].apply(getS)
cleansedTweetDFShort10['Sentiment (Polarity)'] = cleansedTweetDFShort10['text'].apply(getP)

cleansedTweetDFShort10
# Out:
#                  tweetid        date      time      user  \
# 12   1508125473842335749  2022-03-27  16:55:07  38150247
# 21   1504398354565976070  2022-03-17  10:04:52  38150247
# 54   1492872048120668161  2022-02-13  14:43:27  38150247
# 55   1492074452796022791  2022-02-11  09:54:05  38150247
# 56   1492074451432873985  2022-02-11  09:54:05  38150247
# ..                   ...         ...       ...       ...
# 169  1456191852026159105  2021-11-04  09:29:26  38150247
# 172  1454008788638474240  2021-10-29  08:54:44  38150247
# 174  1453697312149151747  2021-10-28  12:17:02  38150247
# 176  1453279700990763012  2021-10-27  08:37:36  38150247
# 177  1453000642365100052  2021-10-26  14:08:43  38150247
#
#                                                   text  \
# 12   Die Saarländerinnen und Saarländer haben sich ...
# 21   Meine persönliche Position ist längst bekannt:...
# 54   Ich freue mich, wenn Sie und Ihr mir ab heute ...
# 55   Für die aktuelle Welle der Pandemie gibt es An...
# 56   Die Corona-Pandemie und auch die Flutkatastrop...
# ..                                                 ...
# 169  Heute jährt sich das Auffliegen des rechtsextr...
# 172  Lieber Norbert, vielen Dank für das große Enga...
# 174  In der Bundesregierung und auch auf anderen Eb...
# 176  Vielen Dank für die Einladung zum Kongress, un...
# 177  Und auch dir, liebe Aydan , meine herzlichsten...
#
#      Personal Opinion (Subjectivity)  Sentiment (Polarity)
# 12                          0.000000              0.675000
# 21                          0.000000              0.175000
# 54                          0.000000              0.333333
# 55                          0.000000              0.500000
# 56                          0.000000              0.350000
# ..                               ...                   ...
# 169                         0.000000             -0.037500
# 172                         0.250000              0.175000
# 174                         0.250000              0.000000
# 176                         0.333333              0.333333
# 177                         0.000000              1.000000
#
# [100 rows x 7 columns]

# %%
# Plot Word Cloud not cleaned

plt.figure(figsize = (20,20))

allWords = ' '.join([txt for txt in cleansedTweetDFShort10['text']])
wordCloud = WordCloud(max_words=500, width=2000, height = 1000, 
                      max_font_size = 1000, collocations=False).generate(allWords)

plt.imshow(wordCloud, interpolation = "bilinear")
plt.axis('off')
plt.show()

# %%
# Defining set containing all stopwords in German. (Stopwords: Word with no relevance for analysis)
# Source for Stopwordlist: https://github.com/stopwords-iso/stopwords-de/blob/master/stopwords-de.json
# Cleaning text from stopwords

# Create copy to work with
cleansedTweetDFShort10copy = cleansedTweetDFShort10.copy()

# Making statement text in lower case
cleansedTweetDFShort10copy['text']=cleansedTweetDFShort10copy['text'].str.lower()

with open('stopwords-de.json','r') as file:
    stopwordlistgerman = json.load(file)

STOPWORDS = set(stopwordlistgerman)

def cleaning_stopwords(text):
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])

cleansedTweetDFShort10copy['text'] = cleansedTweetDFShort10copy['text'].apply(lambda text: cleaning_stopwords(text))
cleansedTweetDFShort10copy['text'].head(10)
# Out:
# 12    saarländerinnen saarländer klar wechsel spitze...
# 21    persönliche position längst bekannt: zeitlich ...
# 54    freue mich, folgt - alles, regierungsarbeit be...
# 55    aktuelle welle pandemie anlass zuversicht: wis...
# 56    corona-pandemie flutkatastrophe sommer gezeigt...
# 57    everyone can be absolutely sure that germany s...
# 60    stärke westlichen antwort lage russisch-ukrain...
# 61    verhindern, welle nächste folgt, virusvariante...
# 62    lage grenze ukraine ernst. klar ist: territori...
# 64    kusel passiert ist, bedrückt sehr. mitgefühl g...
# Name: text, dtype: object

# %%
# Cleaning text from english stopwords
# Source for Stopwordlist: https://countwordsfree.com/stopwords
# Cleaning text from stopwords
with open('stop_words_english.json','r') as file:
    stopwordlistenglish = json.load(file)

STOPWORDS = set(stopwordlistenglish)
def cleaning_stopwords(text):
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])
cleansedTweetDFShort10copy['text'] = cleansedTweetDFShort10copy['text'].apply(lambda text: cleaning_stopwords(text))
cleansedTweetDFShort10copy['text'].head(10)
# Out:
# 12    saarländerinnen saarländer klar wechsel spitze...
# 21    persönliche position längst bekannt: zeitlich ...
# 54    freue mich, folgt - alles, regierungsarbeit be...
# 55    aktuelle welle pandemie anlass zuversicht: wis...
# 56    corona-pandemie flutkatastrophe sommer gezeigt...
# 57    absolutely germany stands allies united russia...
# 60    stärke westlichen antwort lage russisch-ukrain...
# 61    verhindern, welle nächste folgt, virusvariante...
# 62    lage grenze ukraine ernst. klar ist: territori...
# 64    kusel passiert ist, bedrückt sehr. mitgefühl g...
# Name: text, dtype: object

# %%
#Remove punctations

import string
english_punctuations = string.punctuation
punctuations_list = english_punctuations
def cleaning_punctuations(text):
    translator = str.maketrans('', '', punctuations_list)
    return text.translate(translator)
cleansedTweetDFShort10copy['text']= cleansedTweetDFShort10copy['text'].apply(lambda x: cleaning_punctuations(x))
cleansedTweetDFShort10copy['text'].head(10)
# Out:
# 12    saarländerinnen saarländer klar wechsel spitze...
# 21    persönliche position längst bekannt zeitlich b...
# 54    freue mich folgt  alles regierungsarbeit betri...
# 55    aktuelle welle pandemie anlass zuversicht wiss...
# 56    coronapandemie flutkatastrophe sommer gezeigt ...
# 57    absolutely germany stands allies united russia...
# 60    stärke westlichen antwort lage russischukraini...
# 61    verhindern welle nächste folgt virusvarianten ...
# 62    lage grenze ukraine ernst klar ist territorial...
# 64    kusel passiert ist bedrückt sehr mitgefühl gil...
# Name: text, dtype: object

# %%
# Plot Word Cloud after cleaning
plt.figure(figsize = (20,20))
cleanedwords = ' '.join([txt for txt in cleansedTweetDFShort10copy['text']])
wordCloud = WordCloud(max_words = 500, width=2000, height = 1000, max_font_size = 1000, 
                      collocations=False).generate(cleanedwords)

plt.imshow(wordCloud, interpolation = "bilinear")
plt.axis('off')
plt.show()

# %%
# Sentiment Analysis with TextBlob 

# Create a function to compute analysis

def getA(score):
    if score < 0:
        return 'negative'
    elif score == 0:
        return 'neutral'
    else:
        return 'positive'

cleansedTweetDFShort10['Analysis'] = cleansedTweetDFShort10['Sentiment (Polarity)'].apply(getA)
cleansedTweetDFShort10
# Out:
#                  tweetid        date      time      user  \
# 12   1508125473842335749  2022-03-27  16:55:07  38150247
# 21   1504398354565976070  2022-03-17  10:04:52  38150247
# 54   1492872048120668161  2022-02-13  14:43:27  38150247
# 55   1492074452796022791  2022-02-11  09:54:05  38150247
# 56   1492074451432873985  2022-02-11  09:54:05  38150247
# ..                   ...         ...       ...       ...
# 169  1456191852026159105  2021-11-04  09:29:26  38150247
# 172  1454008788638474240  2021-10-29  08:54:44  38150247
# 174  1453697312149151747  2021-10-28  12:17:02  38150247
# 176  1453279700990763012  2021-10-27  08:37:36  38150247
# 177  1453000642365100052  2021-10-26  14:08:43  38150247
#
#                                                   text  \
# 12   Die Saarländerinnen und Saarländer haben sich ...
# 21   Meine persönliche Position ist längst bekannt:...
# 54   Ich freue mich, wenn Sie und Ihr mir ab heute ...
# 55   Für die aktuelle Welle der Pandemie gibt es An...
# 56   Die Corona-Pandemie und auch die Flutkatastrop...
# ..                                                 ...
# 169  Heute jährt sich das Auffliegen des rechtsextr...
# 172  Lieber Norbert, vielen Dank für das große Enga...
# 174  In der Bundesregierung und auch auf anderen Eb...
# 176  Vielen Dank für die Einladung zum Kongress, un...
# 177  Und auch dir, liebe Aydan , meine herzlichsten...
#
#      Personal Opinion (Subjectivity)  Sentiment (Polarity)  Analysis
# 12                          0.000000              0.675000  positive
# 21                          0.000000              0.175000  positive
# 54                          0.000000              0.333333  positive
# 55                          0.000000              0.500000  positive
# 56                          0.000000              0.350000  positive
# ..                               ...                   ...       ...
# 169                         0.000000             -0.037500  negative
# 172                         0.250000              0.175000  positive
# 174                         0.250000              0.000000   neutral
# 176                         0.333333              0.333333  positive
# 177                         0.000000              1.000000  positive
#
# [100 rows x 8 columns]

# %%
sortedDf = cleansedTweetDFShort10.sort_values(by=['Sentiment (Polarity)'])

#sortedDf = sortedDf.astype({'Analysis':'string'})
print(sortedDf.dtypes)
sortedDf.reset_index(inplace=True, drop=True) # Reset index
sortedDf.head()
# Out:
# tweetid                             object
# date                                object
# time                                object
# user                                object
# text                                string
# Personal Opinion (Subjectivity)    float64
# Sentiment (Polarity)               float64
# Analysis                            object
# dtype: object
#                tweetid        date      time      user  \
# 0  1458712837417807873  2021-11-11  08:26:56  38150247
# 1  1458004091834179586  2021-11-09  09:30:38  38150247
# 2  1485520128980701187  2022-01-24  07:49:33  38150247
# 3  1490374584448733191  2022-02-06  17:19:25  38150247
# 4  1458004089086824450  2021-11-09  09:30:37  38150247
#
#                                                 text  \
# 0  Die Corona-Lage ist besorgniserregend - was wi...
# 1  Das heutige Datum sollte uns mahnen und Mut ma...
# 2  Wer sich entscheidet, sich nicht impfen zu las...
# 3  Die Stärke der westlichen Antwort auf die Lage...
# 4  Für eine düstere Zeit steht der 911938: Synago...
#
#    Personal Opinion (Subjectivity)  Sentiment (Polarity)  Analysis
# 0                             0.00             -1.000000  negative
# 1                             0.00             -0.500000  negative
# 2                             0.00             -0.466667  negative
# 3                             0.00             -0.333333  negative
# 4                             0.25             -0.250000  negative

# %%
# Show texts with Polarity and Analysis 

# Problem erkannt: Er schreibt sowohl englisch als auch deutsch

sortedDf

for i in range (0, sortedDf.shape[0]):
    print(sortedDf['text'][i])
    print(sortedDf['Personal Opinion (Subjectivity)'][i])
    print(sortedDf['Sentiment (Polarity)'][i])
    print(sortedDf['Analysis'][i])
    print()
# Out:
# Die Corona-Lage ist besorgniserregend - was wir tun und an gesetzlichen Änderungen heute einbringen, dazu spreche ich gleich im Bundestag👇
# 0.0
# -1.0
# negative
#
# Das heutige Datum sollte uns mahnen und Mut machen: Wir müssen gegen Judenhass und Rassismus aufstehen und für den Zusammenhalt und den Respekt in der Gesellschaft kämpfen. NieWieder
# 0.0
# -0.5
# negative
#
# Wer sich entscheidet, sich nicht impfen zu lassen, trifft die Entscheidung nicht für sich allein. Er entscheidet mit über das Schicksal all derer, die sich deshalb infizieren. Mein Interview zu Corona, einer Impfpflicht und der Situation in der Ukraine:
# 0.0
# -0.4666666666666666
# negative
#
# Die Stärke der westlichen Antwort auf die Lage an der russisch-ukrainischen Grenze liegt darin, dass wir völlig einheitlich handeln. Denn jetzt geht es darum, Krieg in Europa zu verhindern. Mein Interview mit _BaB vor der Reise nach 🇺🇸: s
# 0.0
# -0.3333333333333333
# negative
#
# Für eine düstere Zeit steht der 911938: Synagogen wurden in Brand gesetzt, Geschäfte und Läden geplündert, tausende Jüdinnen und Juden verhaftet und getötet – und viele haben mitgemacht beim staatlich betriebenen Antisemitismus und Rassismus. Reichspogromnacht
# 0.25
# -0.25
# negative
#
# Wir müssen jetzt zusammenhalten. Dafür haben wir heute weitreichendere Maßnahmen als bisher beschlossen: Flächendeckend 2G, 3G am Arbeitsplatz und in Bus und Bahn. Außerdem weiten wir Impfangebote massiv aus - für Auffrischungsimpfungen. Infektionsschutzgesetz
# 0.0
# -0.25
# negative
#
# Wir müssen verhindern, dass eine Welle auf die nächste folgt, etwa durch neue Virusvarianten. Dafür braucht es eine höhere Impfquote. Ich hoffe, die Empfehlung der Stiko von Novavax überzeugt viele Bürgerinnen und Bürger, die bislang bei der Impfung gezögert haben.
# 0.08333333333333333
# -0.25
# negative
#
# Wir etablieren einen Krisenstab und entwickeln einen neuen, präzisen Umgang mit den aktuellen Herausforderungen zu Corona und Omicron. Wir werden alles tun, was nötig ist. Es gibt nichts, was nicht in Betracht gezogen werden kann.
# 0.0
# -0.2333333333333333
# negative
#
# Die meisten Bürger*innen sind geimpft. Weil eine laute Minderheit dagegen ist und radikal vorgeht, dürfen wir nicht der ganzen Gesellschaft Spaltung unterstellen. Wir müssen uns mit anderen Meinungen auseinandersetzen - aber wo Menschen bedroht werden, müssen wir dagegen stehen.
# 0.0
# -0.2333333333333333
# negative
#
# Daneben brauchen wir viele Maßnahmen, die wir ebenfalls beschlossen haben: 2G- und 2G+-Beschränkungen für Freizeitveranstaltungen, 2G im Einzelhandel, strenge Kontaktbeschränkungen im privaten Bereich, wenn Ungeimpfte teilnehmen. (2/4)
# 0.25
# -0.175
# negative
#
# Antisemitismus, Hassreden und Gewalt gegen Menschen jüdischen Glaubens nehmen zu, in Deutschland und auch in vielen anderen Ländern weltweit. Das dürfen wir nicht zulassen: Wir müssen Antisemitismus bekämpfen – überall und in allen Formen. WeRemember
# 0.3333333333333333
# -0.16666666666666666
# negative
#
# Helft uns allen, vermeidbares Leid zu verhindern. Lasst euch impfen, schützt euer Leben und das der anderen. JKLive
# 0.0
# -0.10000000000000002
# negative
#
# Wir treiben die Impfkampagne weiter massiv voran, mit mobilen Teams, Ärzt*innen, Apotheken und Bundeswehr-Impfteams. Die beschlossene Impfpflicht zum Schutz vulnerabler Gruppen setzen wir konsequent durch, die Diskussion über eine allgemeine Impfpflicht setzen wir fort. (3/4)
# 0.0
# -0.10000000000000002
# negative
#
# Heute jährt sich das Auffliegen des rechtsextremen NSU zum10. Mal. Die Opfer und Angehörigen dieses Terrors haben unendliches Leid erfahren. Wir sind es ihnen schuldig, Rechtsextremismus entschlossen zu bekämpfen, er ist eine große Bedrohung für unsere Gesellschaft.
# 0.0
# -0.037500000000000006
# negative
#
# I am delighted by our good discussions and look forward to continue our dialogue!
# 0.0
# 0.0
# neutral
#
# We are currently witnessing a remarkable revival of Social Democratic and progressive parties across Europe and the world. Let us continue working together closely to shape the future of our countries.
# 0.0
# 0.0
# neutral
#
# Wir müssen Dinge anders machen. Deshalb wird General Breuer künftig den Krisenstab im Kanzleramt leiten. Ich bin ihm dankbar, denn wir müssen bis Ende 201 bis zu 30 Millionen Bürger*innen impfen - die größte Operation, die seit langer Zeit gemeistert werden musste. 1/4)
# 0.0
# 0.0
# neutral
#
# Der Koalitionsvertrag steht. Jetzt werben wir in der Partei um Zustimmung, damit die neue Fortschritts-Regierung loslegen kann. Packen wir’s an!
# 0.0
# 0.0
# neutral
#
# Grattis, kära statsminister! Congratulations, dear Magdalena! Your election is historic. I wish you all the best for the tasks ahead. Only together we can tackle the pressing challenges of our time and make Europe stronger. I am looking forward to working with you. Lycka till!
# 0.0
# 0.0
# neutral
#
# Für die Demokratie und das Ende des1. Weltkrieges steht der 91118. Der Sozialdemokrat Philipp Scheidemann rief die erste deutsche Republik aus. Seine Worte: Das Volk hat auf ganzer Linie gesiegt.
# 0.0
# 0.0
# neutral
#
# Neben dem neuen Krisenstab wollen wir uns regelmäßig von einem Expertengremium beraten lassen aus Wissenschaftlerinnen und Wissenschaftlern – nicht nur die Bundesregierung, sondern auch der Bundestag und die Ministerpräsident*innen. (3/4)
# 0.0
# 0.0
# neutral
#
# And Stefan, I am speaking for the entire when I say: Thank you for the trustful collaboration with us in Germany throughout the past years!
# 0.0
# 0.0
# neutral
#
# Heute stimmen wir in der über den Koalitionsvertrag ab. Wir treten ein für eine lebenswerte Zukunft, für mehr Respekt, für Fortschritt. Wir wollen eine Regierung bilden, die das Land nach vorne bringt. Der Aufbruch für die Zwanzigerjahre ist möglich. PackenWirEsAn!
# 0.2
# 0.0
# neutral
#
# Unsere Hauptstadt braucht ein gutes Management und jemanden, der alle Bürgerinnen und Bürger im Blick hat - jemanden wie dich, . Viel Erfolg als Regierende Bürgermeisterin!
# 0.5
# 0.0
# neutral
#
# Ich werde dem Bundespräsidenten 4 Frauen und 3 Männer als Minister*innen vorschlagen, die gemeinsam für die mit mir die Geschicke des Landes leiten sollen. Das entspricht der Gesellschaft, in der wir leben - die Hälfte der Macht gehört den Frauen. 1/5)
# 0.0
# 0.0
# neutral
#
# Die Pandemie hat uns die Schwächen des Gesundheitssystems aufgezeigt. In Zukunft wird jemand vom Fach sich dessen annehmen: _Lauterbach. Die wirtschaftliche Zusammenarbeit und Entwicklung wird verantworten, sie beherrscht das internationale Parkett. (4/5)
# 0.0
# 0.0
# neutral
#
# Ich habe „Ja“ gesagt.
# 0.0
# 0.0
# neutral
#
# Klimaschutz gibt es nicht zum Nulltarif. Wir haben viele Investitionen für Deutschland eingeplant. Weil wir nur so den menschengemachten Klimawandel aufhalten, klimaneutral wirtschaften und technologisch vorne in der Welt mit dabei sein können. Ja, das geht! Koalitionsvertrag
# 0.2
# 0.0
# neutral
#
# Wir haben ehrgeizige Vorhaben: Wir wollen bis Ende des Jahres 30 Millionen Bürgerinnen und Bürger impfen und boostern. Darauf haben wir uns heute bei der MPK geeinigt. Die Impfung ist das wichtigste Mittel, das wir haben. 1/4)
# 0.0
# 0.0
# neutral
#
# Es gibt viele weitere Maßnahmen, die wir ergreifen müssen: flächendeckend 2G, auch für Gaststätten, Freizeitveranstaltungen und den Handel. Wir werden private Kontakte einschränken müssen, sodass Ungeimpfte sich nur noch mit wenigen Personen treffen können. (2/4)
# 0.6666666666666666
# 0.0
# neutral
#
# Dass wir jetzt einen Aufbruch spüren für unser Land, ist die Leistung der ganzen . Weil wir auf Respekt setzen und es ernst meinen. Und darum wird es auch der neuen Regierung in den kommenden Jahren gehen - um Respekt. Ich freue mich auf das, was kommt! spdbpt1
# 0.0
# 0.0
# neutral
#
# Die Erhöhung des Mindestlohns auf12 Euro ist für mich eines unserer wichtigsten Gesetze und eine Frage des Respekts vor der Leistung von Arbeitnehmerinnen und Arbeitnehmern. Ich freue mich, dass es jetzt auf den Weg gebracht wird! sdYTmAILO
# 0.0
# 0.0
# neutral
#
# In der Bundesregierung und auch auf anderen Ebenen muss sichtbar werden, dass Frauen die Hälfte der Gesellschaft sind. Das verstehe ich als dringende Aufgabe auch von uns Männern. Klar: Mehr Macht für Frauen bedeutet weniger Macht für Männer. Es ist Zeit für Parität in der Macht.
# 0.25
# 0.0
# neutral
#
# Congratulations on your great victory ! I am very delighted that you will continue to serve Portugal as a true advocate of social justice. Let us take on the challenges of our time together and build a better and stronger Europe!
# 0.0
# 0.0
# neutral
#
# Die Beschränkungen für Ungeimpfte bleiben – 3G am Arbeitsplatz, in Bussen und Bahnen, 2G im Einzelhandel. Clubs und Diskos bleiben bis auf Weiteres geschlossen. Überregionale Großveranstaltungen finden ohne Publikum statt, das gilt insbesondere für Fußballspiele. (4/5)
# 0.0
# 0.0
# neutral
#
# Wir fordern die kritische Infrastruktur auf, ihre Pandemiepläne zu aktualisieren. Auch für Geimpfte sind ab dem 2812 private Treffen auf10 Personen beschränkt – das gilt auch für Silvester. Außerdem gilt zum Jahreswechsel ein Ansammlungs- und Feuerwerksverbot. (3/5)
# 0.0
# 0.0
# neutral
#
# Die Impfkampagne wird auch über die Feiertage weiterlaufen. 30 Millionen Impfungen bis Ende des Jahres, und noch einmal 30 Millionen bis Ende Januar  – das ist unser Ziel. Wir wollen eine Impfquote von 80 Prozent. (2/5)
# 0.0
# 0.0
# neutral
#
# In unserer Kabinettsklausur heute geht es auch darum, dass wir schneller werden – beim Ausbau der erneuerbaren Energien, beim Wohnungsbau, bei der digitalen Infrastruktur. Mit mehr Tempo ist ein Aufbruch für unser Land möglich, und er ist nötig.
# 0.5
# 0.0
# neutral
#
# Congratulations on your election as the new leader of the , Magdalena! The delegates and members could not have made a better choice. You will do an outstanding job leading the party and, hopefully, serving the country as the next Prime Minister.
# 0.0
# 0.0
# neutral
#
# Ich kann alle verstehen, die gerade vor Weihnachten nichts mehr hören wollen von Mutationen und Virusvarianten. Aber wir dürfen die Augen vor der Omikron-Welle nicht verschließen, die sich vor uns auftürmt. Deshalb haben wir heute in der MPK neue Maßnahmen beschlossen. 1/5)
# 0.25
# 0.0
# neutral
#
# Die Lage an der Grenze der Ukraine ist sehr ernst. Klar ist: Die territoriale Souveränität des Landes zu verletzen, hätte für Russland einen hohen Preis. Wir unternehmen alles, um über unterschiedliche Gesprächsformate aus dieser verfahrenen Situation herauszukommen. sc1XnU
# 0.0
# 0.0
# neutral
#
# Everyone can be absolutely sure that Germany stands side by side with its allies and especially the United States when it comes to Russia and the Ukraine. We are prepared to take all necessary steps together. There is no disagreement in this situation. sOxCcmuf
# 0.0
# 0.0
# neutral
#
# Eine längst überfällige Modernisierung: Wir streichen 19a aus dem Strafgesetzbuch. Ärztinnen und Ärzte müssen über Schwangerschaftsabbrüche informieren können, ohne eine Strafverfolgung befürchten zu müssen.
# 0.0
# 0.0
# neutral
#
# Was in Kusel passiert ist, bedrückt mich sehr. Mein Mitgefühl gilt den Angehörigen der beiden jungen Opfer. Und ich denke an die vielen Polizist*innen, die jeden Tag ihr Leben riskieren, um uns Bürger*innen zu schützen. Wir müssen die Hintergründe der Tat schnell aufklären.
# 0.125
# 0.012499999999999983
# positive
#
# Abermals heißt es zu Weihnachten: Kontakte reduzieren. Ich weiß, das fällt gerade jetzt besonders schwer. Aber wenn wir zusammenstehen und uns impfen lassen, kommen wir durch diese Krise. Ich wünsche uns allen trotz dieser Umstände ein friedliches Fest und frohe Weihnachten!
# 0.0
# 0.037500000000000006
# positive
#
# Ich bin froh, dass in dieser schwierigen Lage der Schulterschluss funktioniert, dass die Parteipolitik in den Hintergrund und das Wohl der Bürgerinnen und Bürger in den Vordergrund rückt. Jetzt ist die Zeit für Solidarität. (4/4)
# 0.0
# 0.05000000000000001
# positive
#
# Die Bilder von der polnischen Grenze sind erschütternd. Lukaschenko schickt Menschen bei eisigen Temperaturen auf den Weg, das muss Konsequenzen haben. Wir müssen mit aller Härte gegen das Minsker Regime vorgehen und dringend humanitäre Hilfe für die Menschen sicherstellen.
# 0.0
# 0.10000000000000002
# positive
#
# Die Ampel steht. Wir haben uns auf einen Koalitionsvertrag geeinigt. Wir wollen uns etwas zutrauen und mehr Fortschritt wagen – beim Klimaschutz, beim Umbau unserer Industrie, bei der Modernisierung des Landes, bei der Stärkung des gesellschaftlichen Zusammenhalts. 1/4)
# 0.08333333333333333
# 0.11666666666666665
# positive
#
# Das Schöne am Festakt 75 Jahre _fraktion_nw: Eingerahmt von so vielen besonderen Gästen wie , Rolf Mützenich, Hannelore Kraft, Franz Müntefering, _Muentefering &amp; vielen mehr macht der Besuch gleich noch mal mehr Freude. Danke für die Einladung, !
# 0.375
# 0.125
# positive
#
# Morgen stimmt der Bundestag ab. Damit wir gut durch den Winter kommen, müssen wir uns gemeinsam anstrengen, auch wenn es manchem nach so vielen Monaten der Pandemie schwer fallen mag.
# 0.125
# 0.125
# positive
#
# Viele haben verstanden, dass sich eine verstärkte internationale Zusammenarbeit im Rahmen eines Klimaclubs lohnt. Es ist auch ein gutes Zeichen, dass die USA wieder auf internationale Kooperation setzen. Der Klimaclub erhält viel Zuspruch - das ist gut so. COP26
# 0.375
# 0.125
# positive
#
# Die Sicherheit wird in Zukunft in den Händen starker Frauen liegen. Deshalb werde ich als Verteidigungsministerin Christine Lambrecht vorschlagen. Der Wohnungsbau soll wieder die Wichtigkeit erlangen, die es schonmal hatte. _geywitz wird sich das zur Aufgabe machen. (3/5)
# 0.0
# 0.13999999999999999
# positive
#
# Gewalt gegen Frauen ist leider weit verbreitete Alltagskriminalität. Der gefährlichste Ort für Frauen ist immer noch das eigene Zuhause. Wichtig ist: Häusliche Gewalt ist keine Privatangelegenheit. Es ist ein gesellschaftliches Thema, das uns alle angeht. TagGegenGewaltAnFrauen
# 0.0
# 0.13999999999999999
# positive
#
# Omikron setzt sich immer mehr durch. Der beste Schutz gegen eine schwere Corona-Infektion ist und bleibt das Impfen. Nun sind 75 % der Deutschen mindestens einmal geimpft. Eine wichtige Wegmarke. Als nächstes sollten wir die 80%-Marke anstreben.
# 0.2
# 0.13999999999999999
# positive
#
# Meine persönliche Position ist längst bekannt: Ich bin für eine zeitlich befristete allgemeine Impfnachweispflicht. Dafür spricht alle Erfahrung der letzten zwei Jahre.
# Wir alle haben jetzt lange auf vieles verzichtet. Das Erreichte dürfen wir nicht wieder aufs Spiel setzen.
# 0.0
# 0.175
# positive
#
# Wir müssen unser Land winterfest machen. Das Virus ist unter uns und bedroht unsere Gesundheit. Es gilt jetzt, Maßnahmen zu ergreifen, um alle vor Corona zu schützen. Bundestag 1/5)
# 0.0
# 0.175
# positive
#
# Wir haben mit Arbeitnehmer*innen und Arbeitgeber*innen gesprochen und werden 3G am Arbeitsplatz einführen. Dafür ist es notwendig, wieder kostenlose Tests für alle anzubieten. Das werden wir tun. (4/5)
# 0.0
# 0.175
# positive
#
# Lieber Norbert, vielen Dank für das große Engagement, die vertrauensvolle Zusammenarbeit und die Unterstützung in den letzten beiden Jahren. Gemeinsam mit , und Rolf Mützenich haben wir die SPD zu neuen Erfolgen geführt  - das ist auch dein Verdienst.
# 0.25
# 0.175
# positive
#
# Und trotz aller Freude darüber, ist die Corona-Lage gerade sehr ernst. Wir müssen als Land zusammenhalten und die Gesundheit der Bürgerinnen und Bürger schützen. Viele sollten sich jetzt einen Ruck geben und sich impfen lassen! Wenn nicht für sich selbst, dann für uns alle.
# 0.25
# 0.175
# positive
#
# Corona ist nicht besiegt. Tag für Tag ereilen uns neue Rekorde. Seit heute sind neue Maßnahmen in Kraft, die wir konsequent umsetzen, um die Infektionszahlen zu senken. Darüber hinaus wird die neue Bundesregierung folgende Schritte sofort nach Amtsübernahme einleiten: 1/4)
# 0.0
# 0.175
# positive
#
# Heute beginnt für Jüdinnen und Juden das Lichterfest Chanukah, und auch für alle Christinnen und Christen fängt eine besondere Zeit an: der Advent. Sie eint das Anzünden der ersten Kerze - ich wünsche allen viel Freude dabei und besinnliche Stunden mit den Liebsten!
# 0.25
# 0.175
# positive
#
# Die Änderungen im Infektionsschutzgesetz geben den Ländern die Möglichkeit, 3G und 2G für Veranstaltungen, in Gaststätten, in Kinos und Theatern einzuführen. Ich bin froh, dass viele Länder sich für 2G entscheiden, das ist ein wichtiger Fortschritt! (3/5)
# 0.1111111111111111
# 0.18888888888888888
# positive
#
# Ich bin froh, dass wir miteinander vereinbart haben, den Mindestlohn in einem Schritt auf12 Euro zu erhöhen. Und dass wir eine Kindergrundsicherung einführen, die Armut verhindern wird. Zugleich halten wir die Rente, wie versprochen, stabil. (2/4)
# 0.0
# 0.2125
# positive
#
# Wir sind in dieser Lage, weil nicht genug Menschen geimpft sind. Deshalb ist es richtig, dass die Abgeordneten im Bundestag nach ihrem Gewissen über eine Impfpflicht entscheiden, ab dem Zeitpunkt, bei dem jeder, der sich jetzt impfen lässt, eine Zweitimpfung erhalten hat. (4/4)
# 0.0
# 0.21666666666666667
# positive
#
# Wir müssen die Impfzentren wiedereröffnen, auch mit Mitteln des Bundes, damit sich schnell viele boostern lassen. Wer in einem Pflegeheim arbeitet und nicht geimpft ist, muss sich täglich testen, nur so können wir die besonders gefährdeten Älteren schützen. (2/5)
# 0.3333333333333333
# 0.2333333333333333
# positive
#
# Wir überprüfen die MPK-Beschlüsse so rechtzeitig, dass wir weitere Maßnahmen bei der nächsten MPK beschließen können.
#
# Die neue Bundesregierung wird alles Erforderliche tun, um unser Land gut durch diese Zeit zu bringen. Gemeinsam brechen wir die vierte Welle. (4/4)
# 0.0
# 0.25
# positive
#
# Wir setzen einen Bund-Länder-Krisenstab im Bundeskanzleramt ein. Und eine Expert*innengruppe aus Virolog*innen, Epidemiolog*innen &amp; Psycholog*innen beurteilt täglich die Lage. Wir brauchen wissenschaftlichen Sachverstand, um zu klugen Erkenntnissen zu kommen. (2/4)
# 0.0
# 0.25
# positive
#
# Die erste Innenministerin Deutschlands soll werden. Bei ihr liegt die Sicherheit des Landes in erfahrenen Händen. _heil war ein sehr erfolgreicher, hartnäckiger und kluger Arbeits- und Sozialminister - diese Aufgabe soll er weiterhin ausüben. (2/5)
# 0.0
# 0.25
# positive
#
# Was jetzt wichtig ist: Dass wir noch viele überzeugen, sich impfen zu lassen. Wir sehen auf den Intensivstationen: Es reicht nicht. Es müssen sich mehr Bürgerinnen und Bürger schützen. Wir müssen millionenfach boostern, viel mehr testen und 2G-Regeln nutzen.
# 0.375
# 0.3
# positive
#
# Und wir haben vereinbart, im Kampf gegen hohe Mieten den Wohnungsbau voranzutreiben: 400.000 neue Wohnungen pro Jahr, davon100.000 öffentlich gefördert. Wir bauen die digitale Infrastruktur aus, damit überall schnelles Internet und verlässlicher Mobilfunkempfang herrscht. (3/4)
# 0.0
# 0.3333333333333333
# positive
#
# Das Bundeskanzleramt wird _Schmidt_ leiten. Ich bin dankbar, dass er diese Aufgabe übernimmt, und wir die vertrauensvolle Arbeit der vergangenen Jahre fortsetzen. (5/5)
# 0.0
# 0.3333333333333333
# positive
#
# Vielen Dank für die Einladung zum Kongress, und _vassiliadis! Wir müssen die Industrie modernisieren, um den menschengemachten Klimawandel aufzuhalten. Klar ist: Diese Transformation geht nur gemeinsam mit den Gewerkschaften!
# 0.3333333333333333
# 0.3333333333333333
# positive
#
# Ich freue mich, wenn Sie und Ihr mir ab heute auch unter folgt - für alles, was meine Regierungsarbeit betrifft. Auf diesem Account geht es ab jetzt um die und meinen Wahlkreis. Und auch hier möchte ich sagen: Herzlichen Glückwunsch, Frank-Walter!
# 0.0
# 0.3333333333333333
# positive
#
# Wir beschränken Großveranstaltungen, und stellen sicher, dass bei hohen Inzidenzen Clubs und Diskotheken nicht mehr betrieben werden. Wir brauchen die Impfpflicht jetzt dort, wo Menschen besonders geschützt werden müssen, in Alten- und Pflegeheimen, in Krankenhäusern. (3/4)
# 0.16666666666666666
# 0.3499999999999999
# positive
#
# Die Corona-Pandemie und auch die Flutkatastrophe im vergangenen Sommer haben gezeigt: Wenn es darauf ankommt, stehen wir in Deutschland zusammen - Bund, Länder, Kommunen. Das ist ein großer Lichtblick und dafür danke ich dem Bundesrat, der Herzkammer unseres Föderalismus.
# 0.0
# 0.35
# positive
#
# Der Aufbruch beginnt. Wenn unsere Regierungsarbeit so gut funktioniert, wie die Zusammenarbeit in den vergangenen Wochen, liegt vor uns eine gute Zeit. Direkt zu Beginn müssen wir eine schwere Aufgabe bewältigen: die Corona-Krise bekämpfen. Das wird unsere ganze Kraft fordern.
# 0.0
# 0.425
# positive
#
# Wir sind finanzpolitisch auf Kurs, es geht weiter aufwärts. Der Arbeitsmarkt war in der Krise robust und wir können mit höheren Einnahmen rechnen. Das sind erfreuliche Zahlen! Steuerschätzung
# 0.0
# 0.425
# positive
#
# Für die aktuelle Welle der Pandemie gibt es Anlass zur Zuversicht: Wissenschaftliche Prognosen zeigen, dass der Höhepunkt von Omikron in Sicht ist. Das erlaubt uns, beim nächsten Bund-Länder-Treffen einen ersten Öffnungsschritt und weitere für das Frühjahr in den Blick zu nehmen.
# 0.0
# 0.5
# positive
#
# Wir haben genug Impfstoff, aber keineswegs alle haben sich impfen lassen. Deshalb möchte ich allen Bürgerinnen und Bürgern sagen, die es bisher nicht gemacht haben: Lassen Sie sich impfen, es ist wichtig für Ihre Gesundheit, und es ist wichtig für unser Land. (5/5)
# 0.0
# 0.5
# positive
#
# Herzlichen Glückwunsch zur Wiederwahl als Ministerpräsidentin, ! Ich freue mich, dass dir so viele Bürgerinnen und Bürger in Mecklenburg-Vorpommern ihre Stimme gegeben haben und wünsche dir jetzt viel Erfolg für die kommenden fünf Jahre!
# 0.5
# 0.5
# positive
#
# Heute hat das Abgeordnetenhaus an die Spitze Berlins gewählt. Du bist die, die das kann, Franziska - Gratulation und viel Erfolg als Regierende Bürgermeisterin!
# 0.5
# 0.5
# positive
#
# 98,8 Prozent Zustimmung bei der zu unserem Koalitionsvertrag und damit zur Fortschrittsregierung - das freut mich wirklich sehr. Und jetzt machen wir uns an die Arbeit!
# 0.0
# 0.5
# positive
#
# Glück auf, liebe - auf dass du das Vize im nächsten Jahr streichen kannst und dann Ministerpräsidentin sein wirst. _Saar
# 0.0
# 0.5
# positive
#
# Wir müssen strukturell Frauen besser vor häuslicher Gewalt schützen. Dazu gehört das Recht auf Schutz vor Gewalt, Frauenhäuser verlässlich zu finanzieren und frauenfeindliche Hasskriminalität besser zu erfassen.
# 0.0
# 0.5166666666666666
# positive
#
# Die Ampel ist ein neues Bündnis, das viele zusammenführt und eine große Kraft hat. Auch zur Bekämpfung der Pandemie: Bis Ende des Jahres wollen wir dafür gesorgt haben, dass 30 Millionen Menschen in Deutschland geboostert werden, ein großer Kraftakt – darum kümmern wir uns.
# 0.25
# 0.5249999999999999
# positive
#
# Wer noch nicht geimpft ist, sollte sich einen Ruck geben. Damit wir all jene schützen, die sich nicht impfen lassen können, allen voran unsere Kinder.
#
# Es waren gute Beratungen im Bundestag und gute Beratungen in der MPK.
# 0.0
# 0.5666666666666667
# positive
#
# Dass wir stärkste Kraft sind, ist der Erfolg der ganzen . Und trotzdem möchte ich mich besonders bedanken: bei , , , Rolf Mützenich. Wir haben es hinbekommen, dass eine geschlossene SPD in den Wahlkampf gegangen ist, und gewonnen hat!
# 0.0
# 0.6166666666666667
# positive
#
# Mein Dank gilt dem Expertenrat für die klare und einhellige Einschätzung, dies ist die Grundlage für unsere politischen Entscheidungen. Wir müssen zusammenstehen und trotzdem Abstand halten, damit unser Land gut durch die nächste Zeit kommt. (5/5)
# 0.0
# 0.6666666666666666
# positive
#
# In diesen Tagen und Wochen haben wir eng, intensiv und mitunter leidenschaftlich und vor allem vertrauensvoll miteinander verhandelt. Das hat mir gut gefallen – und in mir das Gefühl verstärkt, dass hier tatsächlich etwas zusammengewachsen ist als Koalition. (4/4)
# 0.0
# 0.6666666666666666
# positive
#
# Die Saarländerinnen und Saarländer haben sich klar für einen Wechsel an der Spitze ihres Landes entschieden. Und ich bin sicher: Niemand wird ihn besser gestalten als Du, .
#
# Herzlichen Glückwunsch zum überzeugenden Wahlsieg!
#
# ltwSaar22 Saarland
# 0.0
# 0.675
# positive
#
# Danke für Lob und Diskussion auf eurem Bundeskongress, liebe , und Glückwunsch zur Wiederwahl, _rosenthal! Es geht uns darum, für mehr Fortschritt und Respekt in der Gesellschaft zu sorgen.
# 0.25
# 0.675
# positive
#
# Angela Merkel war eine erfolgreiche Kanzlerin. Unermüdlich hat sie sich für unser Land eingesetzt und ist sich in16 Jahren, in denen sich vieles verändert hat, treu geblieben. Ich bin sehr sicher, das wird gelingen: sich fern vom alten neu entfalten. Alles Gute! Zapfenstreich
# 0.0
# 0.77
# positive
#
# Herzlichen Glückwunsch, &amp; ! Der Parteivorsitz ist eine große Ehre und Verpflichtung gegenüber den Bürger*innen, denn sie sind auf eine starke angewiesen. Ich bin sicher: Dafür werden wir gemeinsam mit dem neuen Generalsekretär sorgen.
# 0.0
# 0.7999999999999999
# positive
#
# Herzlichen Glückwunsch zur Wiederwahl an die Spitze der , Dietmar Woidke! Der Wahlerfolg der SPD in Brandenburg ist auch dein Verdienst - mein großer Dank!
# 0.0
# 0.85
# positive
#
# 118,1938,1989 – der 9November ist ein Datum voller Geschichte: Der Fall der Mauer am 911989 ist das Ergebnis einer friedlichen Revolution und der Beweis für die Macht, die wir Bürgerinnen und Bürger haben, wenn wir gemeinsam für unsere Freiheit streiten.
# 0.0
# 1.0
# positive
#
# Ich bedanke mich herzlich bei , der heute sein Amt als Parteivorsitzender abgegeben hat. Ohne sein Engagement in den vergangenen zwei Jahren an der Spitze der Partei wäre der Wahlsieg nicht möglich gewesen.
# 0.0
# 1.0
# positive
#
# Herzlichen Glückwunsch zu diesem guten Ergebnis und der hohen Beteiligung, _FriedrichMerz. Alles Gute für den Parteivorsitz!
# 0.0
# 1.0
# positive
#
# Herzlichen Glückwunsch an die beiden neuen Vorsitzenden der _Gruenen, _Lang und Omid ! Ich freue mich darauf, gemeinsam am Fortschritt für unser Land zu arbeiten und wünsche gutes Gelingen bei der neuen Aufgabe.
# 0.0
# 1.0
# positive
#
# Der -Parteivorstand hat heute Vormittag und für den SPD-Vorsitz vorgeschlagen - ein sehr gutes Team für Fortschritt und Zusammenhalt. Mit beiden arbeite ich seit Jahren sehr vertrauensvoll zusammen.
# 0.0
# 1.0
# positive
#
# Und auch dir, liebe Aydan , meine herzlichsten Glückwünsche zur Wahl als Bundestagsvizepräsidentin. Ich bin froh, dass du in Zukunft das Präsidium des Bundestags mitprägst.
# 0.0
# 1.0
# positive

# %%
# Print Positive tweets

j=1;

for i in range(0, sortedDf.shape[0]):
    if(sortedDf['Analysis'][i] == 'positive'):
        print(str(j) + ') ' + sortedDf['text'][i])
        print(sortedDf['Personal Opinion (Subjectivity)'][i])
        print(sortedDf['Sentiment (Polarity)'][i])
        print(sortedDf['Analysis'][i])
        print()
        j=j+1
# Out:
# 1) Was in Kusel passiert ist, bedrückt mich sehr. Mein Mitgefühl gilt den Angehörigen der beiden jungen Opfer. Und ich denke an die vielen Polizist*innen, die jeden Tag ihr Leben riskieren, um uns Bürger*innen zu schützen. Wir müssen die Hintergründe der Tat schnell aufklären.
# 0.125
# 0.012499999999999983
# positive
#
# 2) Abermals heißt es zu Weihnachten: Kontakte reduzieren. Ich weiß, das fällt gerade jetzt besonders schwer. Aber wenn wir zusammenstehen und uns impfen lassen, kommen wir durch diese Krise. Ich wünsche uns allen trotz dieser Umstände ein friedliches Fest und frohe Weihnachten!
# 0.0
# 0.037500000000000006
# positive
#
# 3) Ich bin froh, dass in dieser schwierigen Lage der Schulterschluss funktioniert, dass die Parteipolitik in den Hintergrund und das Wohl der Bürgerinnen und Bürger in den Vordergrund rückt. Jetzt ist die Zeit für Solidarität. (4/4)
# 0.0
# 0.05000000000000001
# positive
#
# 4) Die Bilder von der polnischen Grenze sind erschütternd. Lukaschenko schickt Menschen bei eisigen Temperaturen auf den Weg, das muss Konsequenzen haben. Wir müssen mit aller Härte gegen das Minsker Regime vorgehen und dringend humanitäre Hilfe für die Menschen sicherstellen.
# 0.0
# 0.10000000000000002
# positive
#
# 5) Die Ampel steht. Wir haben uns auf einen Koalitionsvertrag geeinigt. Wir wollen uns etwas zutrauen und mehr Fortschritt wagen – beim Klimaschutz, beim Umbau unserer Industrie, bei der Modernisierung des Landes, bei der Stärkung des gesellschaftlichen Zusammenhalts. 1/4)
# 0.08333333333333333
# 0.11666666666666665
# positive
#
# 6) Das Schöne am Festakt 75 Jahre _fraktion_nw: Eingerahmt von so vielen besonderen Gästen wie , Rolf Mützenich, Hannelore Kraft, Franz Müntefering, _Muentefering &amp; vielen mehr macht der Besuch gleich noch mal mehr Freude. Danke für die Einladung, !
# 0.375
# 0.125
# positive
#
# 7) Morgen stimmt der Bundestag ab. Damit wir gut durch den Winter kommen, müssen wir uns gemeinsam anstrengen, auch wenn es manchem nach so vielen Monaten der Pandemie schwer fallen mag.
# 0.125
# 0.125
# positive
#
# 8) Viele haben verstanden, dass sich eine verstärkte internationale Zusammenarbeit im Rahmen eines Klimaclubs lohnt. Es ist auch ein gutes Zeichen, dass die USA wieder auf internationale Kooperation setzen. Der Klimaclub erhält viel Zuspruch - das ist gut so. COP26
# 0.375
# 0.125
# positive
#
# 9) Die Sicherheit wird in Zukunft in den Händen starker Frauen liegen. Deshalb werde ich als Verteidigungsministerin Christine Lambrecht vorschlagen. Der Wohnungsbau soll wieder die Wichtigkeit erlangen, die es schonmal hatte. _geywitz wird sich das zur Aufgabe machen. (3/5)
# 0.0
# 0.13999999999999999
# positive
#
# 10) Gewalt gegen Frauen ist leider weit verbreitete Alltagskriminalität. Der gefährlichste Ort für Frauen ist immer noch das eigene Zuhause. Wichtig ist: Häusliche Gewalt ist keine Privatangelegenheit. Es ist ein gesellschaftliches Thema, das uns alle angeht. TagGegenGewaltAnFrauen
# 0.0
# 0.13999999999999999
# positive
#
# 11) Omikron setzt sich immer mehr durch. Der beste Schutz gegen eine schwere Corona-Infektion ist und bleibt das Impfen. Nun sind 75 % der Deutschen mindestens einmal geimpft. Eine wichtige Wegmarke. Als nächstes sollten wir die 80%-Marke anstreben.
# 0.2
# 0.13999999999999999
# positive
#
# 12) Meine persönliche Position ist längst bekannt: Ich bin für eine zeitlich befristete allgemeine Impfnachweispflicht. Dafür spricht alle Erfahrung der letzten zwei Jahre.
# Wir alle haben jetzt lange auf vieles verzichtet. Das Erreichte dürfen wir nicht wieder aufs Spiel setzen.
# 0.0
# 0.175
# positive
#
# 13) Wir müssen unser Land winterfest machen. Das Virus ist unter uns und bedroht unsere Gesundheit. Es gilt jetzt, Maßnahmen zu ergreifen, um alle vor Corona zu schützen. Bundestag 1/5)
# 0.0
# 0.175
# positive
#
# 14) Wir haben mit Arbeitnehmer*innen und Arbeitgeber*innen gesprochen und werden 3G am Arbeitsplatz einführen. Dafür ist es notwendig, wieder kostenlose Tests für alle anzubieten. Das werden wir tun. (4/5)
# 0.0
# 0.175
# positive
#
# 15) Lieber Norbert, vielen Dank für das große Engagement, die vertrauensvolle Zusammenarbeit und die Unterstützung in den letzten beiden Jahren. Gemeinsam mit , und Rolf Mützenich haben wir die SPD zu neuen Erfolgen geführt  - das ist auch dein Verdienst.
# 0.25
# 0.175
# positive
#
# 16) Und trotz aller Freude darüber, ist die Corona-Lage gerade sehr ernst. Wir müssen als Land zusammenhalten und die Gesundheit der Bürgerinnen und Bürger schützen. Viele sollten sich jetzt einen Ruck geben und sich impfen lassen! Wenn nicht für sich selbst, dann für uns alle.
# 0.25
# 0.175
# positive
#
# 17) Corona ist nicht besiegt. Tag für Tag ereilen uns neue Rekorde. Seit heute sind neue Maßnahmen in Kraft, die wir konsequent umsetzen, um die Infektionszahlen zu senken. Darüber hinaus wird die neue Bundesregierung folgende Schritte sofort nach Amtsübernahme einleiten: 1/4)
# 0.0
# 0.175
# positive
#
# 18) Heute beginnt für Jüdinnen und Juden das Lichterfest Chanukah, und auch für alle Christinnen und Christen fängt eine besondere Zeit an: der Advent. Sie eint das Anzünden der ersten Kerze - ich wünsche allen viel Freude dabei und besinnliche Stunden mit den Liebsten!
# 0.25
# 0.175
# positive
#
# 19) Die Änderungen im Infektionsschutzgesetz geben den Ländern die Möglichkeit, 3G und 2G für Veranstaltungen, in Gaststätten, in Kinos und Theatern einzuführen. Ich bin froh, dass viele Länder sich für 2G entscheiden, das ist ein wichtiger Fortschritt! (3/5)
# 0.1111111111111111
# 0.18888888888888888
# positive
#
# 20) Ich bin froh, dass wir miteinander vereinbart haben, den Mindestlohn in einem Schritt auf12 Euro zu erhöhen. Und dass wir eine Kindergrundsicherung einführen, die Armut verhindern wird. Zugleich halten wir die Rente, wie versprochen, stabil. (2/4)
# 0.0
# 0.2125
# positive
#
# 21) Wir sind in dieser Lage, weil nicht genug Menschen geimpft sind. Deshalb ist es richtig, dass die Abgeordneten im Bundestag nach ihrem Gewissen über eine Impfpflicht entscheiden, ab dem Zeitpunkt, bei dem jeder, der sich jetzt impfen lässt, eine Zweitimpfung erhalten hat. (4/4)
# 0.0
# 0.21666666666666667
# positive
#
# 22) Wir müssen die Impfzentren wiedereröffnen, auch mit Mitteln des Bundes, damit sich schnell viele boostern lassen. Wer in einem Pflegeheim arbeitet und nicht geimpft ist, muss sich täglich testen, nur so können wir die besonders gefährdeten Älteren schützen. (2/5)
# 0.3333333333333333
# 0.2333333333333333
# positive
#
# 23) Wir überprüfen die MPK-Beschlüsse so rechtzeitig, dass wir weitere Maßnahmen bei der nächsten MPK beschließen können.
#
# Die neue Bundesregierung wird alles Erforderliche tun, um unser Land gut durch diese Zeit zu bringen. Gemeinsam brechen wir die vierte Welle. (4/4)
# 0.0
# 0.25
# positive
#
# 24) Wir setzen einen Bund-Länder-Krisenstab im Bundeskanzleramt ein. Und eine Expert*innengruppe aus Virolog*innen, Epidemiolog*innen &amp; Psycholog*innen beurteilt täglich die Lage. Wir brauchen wissenschaftlichen Sachverstand, um zu klugen Erkenntnissen zu kommen. (2/4)
# 0.0
# 0.25
# positive
#
# 25) Die erste Innenministerin Deutschlands soll werden. Bei ihr liegt die Sicherheit des Landes in erfahrenen Händen. _heil war ein sehr erfolgreicher, hartnäckiger und kluger Arbeits- und Sozialminister - diese Aufgabe soll er weiterhin ausüben. (2/5)
# 0.0
# 0.25
# positive
#
# 26) Was jetzt wichtig ist: Dass wir noch viele überzeugen, sich impfen zu lassen. Wir sehen auf den Intensivstationen: Es reicht nicht. Es müssen sich mehr Bürgerinnen und Bürger schützen. Wir müssen millionenfach boostern, viel mehr testen und 2G-Regeln nutzen.
# 0.375
# 0.3
# positive
#
# 27) Und wir haben vereinbart, im Kampf gegen hohe Mieten den Wohnungsbau voranzutreiben: 400.000 neue Wohnungen pro Jahr, davon100.000 öffentlich gefördert. Wir bauen die digitale Infrastruktur aus, damit überall schnelles Internet und verlässlicher Mobilfunkempfang herrscht. (3/4)
# 0.0
# 0.3333333333333333
# positive
#
# 28) Das Bundeskanzleramt wird _Schmidt_ leiten. Ich bin dankbar, dass er diese Aufgabe übernimmt, und wir die vertrauensvolle Arbeit der vergangenen Jahre fortsetzen. (5/5)
# 0.0
# 0.3333333333333333
# positive
#
# 29) Vielen Dank für die Einladung zum Kongress, und _vassiliadis! Wir müssen die Industrie modernisieren, um den menschengemachten Klimawandel aufzuhalten. Klar ist: Diese Transformation geht nur gemeinsam mit den Gewerkschaften!
# 0.3333333333333333
# 0.3333333333333333
# positive
#
# 30) Ich freue mich, wenn Sie und Ihr mir ab heute auch unter folgt - für alles, was meine Regierungsarbeit betrifft. Auf diesem Account geht es ab jetzt um die und meinen Wahlkreis. Und auch hier möchte ich sagen: Herzlichen Glückwunsch, Frank-Walter!
# 0.0
# 0.3333333333333333
# positive
#
# 31) Wir beschränken Großveranstaltungen, und stellen sicher, dass bei hohen Inzidenzen Clubs und Diskotheken nicht mehr betrieben werden. Wir brauchen die Impfpflicht jetzt dort, wo Menschen besonders geschützt werden müssen, in Alten- und Pflegeheimen, in Krankenhäusern. (3/4)
# 0.16666666666666666
# 0.3499999999999999
# positive
#
# 32) Die Corona-Pandemie und auch die Flutkatastrophe im vergangenen Sommer haben gezeigt: Wenn es darauf ankommt, stehen wir in Deutschland zusammen - Bund, Länder, Kommunen. Das ist ein großer Lichtblick und dafür danke ich dem Bundesrat, der Herzkammer unseres Föderalismus.
# 0.0
# 0.35
# positive
#
# 33) Der Aufbruch beginnt. Wenn unsere Regierungsarbeit so gut funktioniert, wie die Zusammenarbeit in den vergangenen Wochen, liegt vor uns eine gute Zeit. Direkt zu Beginn müssen wir eine schwere Aufgabe bewältigen: die Corona-Krise bekämpfen. Das wird unsere ganze Kraft fordern.
# 0.0
# 0.425
# positive
#
# 34) Wir sind finanzpolitisch auf Kurs, es geht weiter aufwärts. Der Arbeitsmarkt war in der Krise robust und wir können mit höheren Einnahmen rechnen. Das sind erfreuliche Zahlen! Steuerschätzung
# 0.0
# 0.425
# positive
#
# 35) Für die aktuelle Welle der Pandemie gibt es Anlass zur Zuversicht: Wissenschaftliche Prognosen zeigen, dass der Höhepunkt von Omikron in Sicht ist. Das erlaubt uns, beim nächsten Bund-Länder-Treffen einen ersten Öffnungsschritt und weitere für das Frühjahr in den Blick zu nehmen.
# 0.0
# 0.5
# positive
#
# 36) Wir haben genug Impfstoff, aber keineswegs alle haben sich impfen lassen. Deshalb möchte ich allen Bürgerinnen und Bürgern sagen, die es bisher nicht gemacht haben: Lassen Sie sich impfen, es ist wichtig für Ihre Gesundheit, und es ist wichtig für unser Land. (5/5)
# 0.0
# 0.5
# positive
#
# 37) Herzlichen Glückwunsch zur Wiederwahl als Ministerpräsidentin, ! Ich freue mich, dass dir so viele Bürgerinnen und Bürger in Mecklenburg-Vorpommern ihre Stimme gegeben haben und wünsche dir jetzt viel Erfolg für die kommenden fünf Jahre!
# 0.5
# 0.5
# positive
#
# 38) Heute hat das Abgeordnetenhaus an die Spitze Berlins gewählt. Du bist die, die das kann, Franziska - Gratulation und viel Erfolg als Regierende Bürgermeisterin!
# 0.5
# 0.5
# positive
#
# 39) 98,8 Prozent Zustimmung bei der zu unserem Koalitionsvertrag und damit zur Fortschrittsregierung - das freut mich wirklich sehr. Und jetzt machen wir uns an die Arbeit!
# 0.0
# 0.5
# positive
#
# 40) Glück auf, liebe - auf dass du das Vize im nächsten Jahr streichen kannst und dann Ministerpräsidentin sein wirst. _Saar
# 0.0
# 0.5
# positive
#
# 41) Wir müssen strukturell Frauen besser vor häuslicher Gewalt schützen. Dazu gehört das Recht auf Schutz vor Gewalt, Frauenhäuser verlässlich zu finanzieren und frauenfeindliche Hasskriminalität besser zu erfassen.
# 0.0
# 0.5166666666666666
# positive
#
# 42) Die Ampel ist ein neues Bündnis, das viele zusammenführt und eine große Kraft hat. Auch zur Bekämpfung der Pandemie: Bis Ende des Jahres wollen wir dafür gesorgt haben, dass 30 Millionen Menschen in Deutschland geboostert werden, ein großer Kraftakt – darum kümmern wir uns.
# 0.25
# 0.5249999999999999
# positive
#
# 43) Wer noch nicht geimpft ist, sollte sich einen Ruck geben. Damit wir all jene schützen, die sich nicht impfen lassen können, allen voran unsere Kinder.
#
# Es waren gute Beratungen im Bundestag und gute Beratungen in der MPK.
# 0.0
# 0.5666666666666667
# positive
#
# 44) Dass wir stärkste Kraft sind, ist der Erfolg der ganzen . Und trotzdem möchte ich mich besonders bedanken: bei , , , Rolf Mützenich. Wir haben es hinbekommen, dass eine geschlossene SPD in den Wahlkampf gegangen ist, und gewonnen hat!
# 0.0
# 0.6166666666666667
# positive
#
# 45) Mein Dank gilt dem Expertenrat für die klare und einhellige Einschätzung, dies ist die Grundlage für unsere politischen Entscheidungen. Wir müssen zusammenstehen und trotzdem Abstand halten, damit unser Land gut durch die nächste Zeit kommt. (5/5)
# 0.0
# 0.6666666666666666
# positive
#
# 46) In diesen Tagen und Wochen haben wir eng, intensiv und mitunter leidenschaftlich und vor allem vertrauensvoll miteinander verhandelt. Das hat mir gut gefallen – und in mir das Gefühl verstärkt, dass hier tatsächlich etwas zusammengewachsen ist als Koalition. (4/4)
# 0.0
# 0.6666666666666666
# positive
#
# 47) Die Saarländerinnen und Saarländer haben sich klar für einen Wechsel an der Spitze ihres Landes entschieden. Und ich bin sicher: Niemand wird ihn besser gestalten als Du, .
#
# Herzlichen Glückwunsch zum überzeugenden Wahlsieg!
#
# ltwSaar22 Saarland
# 0.0
# 0.675
# positive
#
# 48) Danke für Lob und Diskussion auf eurem Bundeskongress, liebe , und Glückwunsch zur Wiederwahl, _rosenthal! Es geht uns darum, für mehr Fortschritt und Respekt in der Gesellschaft zu sorgen.
# 0.25
# 0.675
# positive
#
# 49) Angela Merkel war eine erfolgreiche Kanzlerin. Unermüdlich hat sie sich für unser Land eingesetzt und ist sich in16 Jahren, in denen sich vieles verändert hat, treu geblieben. Ich bin sehr sicher, das wird gelingen: sich fern vom alten neu entfalten. Alles Gute! Zapfenstreich
# 0.0
# 0.77
# positive
#
# 50) Herzlichen Glückwunsch, &amp; ! Der Parteivorsitz ist eine große Ehre und Verpflichtung gegenüber den Bürger*innen, denn sie sind auf eine starke angewiesen. Ich bin sicher: Dafür werden wir gemeinsam mit dem neuen Generalsekretär sorgen.
# 0.0
# 0.7999999999999999
# positive
#
# 51) Herzlichen Glückwunsch zur Wiederwahl an die Spitze der , Dietmar Woidke! Der Wahlerfolg der SPD in Brandenburg ist auch dein Verdienst - mein großer Dank!
# 0.0
# 0.85
# positive
#
# 52) 118,1938,1989 – der 9November ist ein Datum voller Geschichte: Der Fall der Mauer am 911989 ist das Ergebnis einer friedlichen Revolution und der Beweis für die Macht, die wir Bürgerinnen und Bürger haben, wenn wir gemeinsam für unsere Freiheit streiten.
# 0.0
# 1.0
# positive
#
# 53) Ich bedanke mich herzlich bei , der heute sein Amt als Parteivorsitzender abgegeben hat. Ohne sein Engagement in den vergangenen zwei Jahren an der Spitze der Partei wäre der Wahlsieg nicht möglich gewesen.
# 0.0
# 1.0
# positive
#
# 54) Herzlichen Glückwunsch zu diesem guten Ergebnis und der hohen Beteiligung, _FriedrichMerz. Alles Gute für den Parteivorsitz!
# 0.0
# 1.0
# positive
#
# 55) Herzlichen Glückwunsch an die beiden neuen Vorsitzenden der _Gruenen, _Lang und Omid ! Ich freue mich darauf, gemeinsam am Fortschritt für unser Land zu arbeiten und wünsche gutes Gelingen bei der neuen Aufgabe.
# 0.0
# 1.0
# positive
#
# 56) Der -Parteivorstand hat heute Vormittag und für den SPD-Vorsitz vorgeschlagen - ein sehr gutes Team für Fortschritt und Zusammenhalt. Mit beiden arbeite ich seit Jahren sehr vertrauensvoll zusammen.
# 0.0
# 1.0
# positive
#
# 57) Und auch dir, liebe Aydan , meine herzlichsten Glückwünsche zur Wahl als Bundestagsvizepräsidentin. Ich bin froh, dass du in Zukunft das Präsidium des Bundestags mitprägst.
# 0.0
# 1.0
# positive

# %%
# Print Negative tweets

j=1;

for i in range(0, sortedDf.shape[0]):
    if(sortedDf['Analysis'][i] == 'negative'):
        print(str(j) + ') ' + sortedDf['text'][i])
        print(sortedDf['Personal Opinion (Subjectivity)'][i])
        print(sortedDf['Sentiment (Polarity)'][i])
        print(sortedDf['Analysis'][i])
        print()
        j=j+1
# Out:
# 1) Die Corona-Lage ist besorgniserregend - was wir tun und an gesetzlichen Änderungen heute einbringen, dazu spreche ich gleich im Bundestag👇
# 0.0
# -1.0
# negative
#
# 2) Das heutige Datum sollte uns mahnen und Mut machen: Wir müssen gegen Judenhass und Rassismus aufstehen und für den Zusammenhalt und den Respekt in der Gesellschaft kämpfen. NieWieder
# 0.0
# -0.5
# negative
#
# 3) Wer sich entscheidet, sich nicht impfen zu lassen, trifft die Entscheidung nicht für sich allein. Er entscheidet mit über das Schicksal all derer, die sich deshalb infizieren. Mein Interview zu Corona, einer Impfpflicht und der Situation in der Ukraine:
# 0.0
# -0.4666666666666666
# negative
#
# 4) Die Stärke der westlichen Antwort auf die Lage an der russisch-ukrainischen Grenze liegt darin, dass wir völlig einheitlich handeln. Denn jetzt geht es darum, Krieg in Europa zu verhindern. Mein Interview mit _BaB vor der Reise nach 🇺🇸: s
# 0.0
# -0.3333333333333333
# negative
#
# 5) Für eine düstere Zeit steht der 911938: Synagogen wurden in Brand gesetzt, Geschäfte und Läden geplündert, tausende Jüdinnen und Juden verhaftet und getötet – und viele haben mitgemacht beim staatlich betriebenen Antisemitismus und Rassismus. Reichspogromnacht
# 0.25
# -0.25
# negative
#
# 6) Wir müssen jetzt zusammenhalten. Dafür haben wir heute weitreichendere Maßnahmen als bisher beschlossen: Flächendeckend 2G, 3G am Arbeitsplatz und in Bus und Bahn. Außerdem weiten wir Impfangebote massiv aus - für Auffrischungsimpfungen. Infektionsschutzgesetz
# 0.0
# -0.25
# negative
#
# 7) Wir müssen verhindern, dass eine Welle auf die nächste folgt, etwa durch neue Virusvarianten. Dafür braucht es eine höhere Impfquote. Ich hoffe, die Empfehlung der Stiko von Novavax überzeugt viele Bürgerinnen und Bürger, die bislang bei der Impfung gezögert haben.
# 0.08333333333333333
# -0.25
# negative
#
# 8) Wir etablieren einen Krisenstab und entwickeln einen neuen, präzisen Umgang mit den aktuellen Herausforderungen zu Corona und Omicron. Wir werden alles tun, was nötig ist. Es gibt nichts, was nicht in Betracht gezogen werden kann.
# 0.0
# -0.2333333333333333
# negative
#
# 9) Die meisten Bürger*innen sind geimpft. Weil eine laute Minderheit dagegen ist und radikal vorgeht, dürfen wir nicht der ganzen Gesellschaft Spaltung unterstellen. Wir müssen uns mit anderen Meinungen auseinandersetzen - aber wo Menschen bedroht werden, müssen wir dagegen stehen.
# 0.0
# -0.2333333333333333
# negative
#
# 10) Daneben brauchen wir viele Maßnahmen, die wir ebenfalls beschlossen haben: 2G- und 2G+-Beschränkungen für Freizeitveranstaltungen, 2G im Einzelhandel, strenge Kontaktbeschränkungen im privaten Bereich, wenn Ungeimpfte teilnehmen. (2/4)
# 0.25
# -0.175
# negative
#
# 11) Antisemitismus, Hassreden und Gewalt gegen Menschen jüdischen Glaubens nehmen zu, in Deutschland und auch in vielen anderen Ländern weltweit. Das dürfen wir nicht zulassen: Wir müssen Antisemitismus bekämpfen – überall und in allen Formen. WeRemember
# 0.3333333333333333
# -0.16666666666666666
# negative
#
# 12) Helft uns allen, vermeidbares Leid zu verhindern. Lasst euch impfen, schützt euer Leben und das der anderen. JKLive
# 0.0
# -0.10000000000000002
# negative
#
# 13) Wir treiben die Impfkampagne weiter massiv voran, mit mobilen Teams, Ärzt*innen, Apotheken und Bundeswehr-Impfteams. Die beschlossene Impfpflicht zum Schutz vulnerabler Gruppen setzen wir konsequent durch, die Diskussion über eine allgemeine Impfpflicht setzen wir fort. (3/4)
# 0.0
# -0.10000000000000002
# negative
#
# 14) Heute jährt sich das Auffliegen des rechtsextremen NSU zum10. Mal. Die Opfer und Angehörigen dieses Terrors haben unendliches Leid erfahren. Wir sind es ihnen schuldig, Rechtsextremismus entschlossen zu bekämpfen, er ist eine große Bedrohung für unsere Gesellschaft.
# 0.0
# -0.037500000000000006
# negative

# %%
#Plot polarity and subjectivity

plt.figure(figsize=(8,6))

for i in range (0, sortedDf.shape[0]):
    plt.scatter(sortedDf['Sentiment (Polarity)'][i], sortedDf['Personal Opinion (Subjectivity)'][i], color='Green')
                
plt.title('Sentiment Analysis')
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')
plt.show()

# %%
# Get the percentage of positive tweets

ptweets = sortedDf[sortedDf.Analysis =="positive"] 

print("Positive Tweets in percent: "+str(round((ptweets.shape[0]/sortedDf.shape[0])*100, 1)) + '%')
# Out:
# Positive Tweets in percent: 57.0%

# %%
# Get the negative of positive tweets

neutweets = sortedDf[sortedDf.Analysis =="neutral"] 

print("Neutral Tweets in percent: "+str(round((neutweets.shape[0]/sortedDf.shape[0])*100, 1)) + '%')
# Out:
# Neutral Tweets in percent: 29.0%

# %%
# Get the negative of positive tweets

ntweets = sortedDf[sortedDf.Analysis =="negative"] 

print("Negative Tweets in percent: "+str(round((ntweets.shape[0]/sortedDf.shape[0])*100, 1)) + '%')
# Out:
# Negative Tweets in percent: 14.0%

# %%
# Show Analysis

sortedDf['Analysis'].value_counts()

plt.title('Sentiment Analysis in %')
plt.xlabel('Sentiment')
plt.ylabel('Counts')
sortedDf['Analysis'].value_counts().plot(kind='bar')
plt.show()

# %%
# Test of spelling correction
